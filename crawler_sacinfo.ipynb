# %%
import urllib2
import time
import pdb
# %pdb on
# for writing chinese characters
# import csv
# output = open("/Volumes/data1/yefei_new14makeup.xls", "w")
# w = csv.writer(output)
import xlwt
output = xlwt.Workbook(encoding = 'utf-8')
table = output.add_sheet('sheet1', cell_overwrite_ok = False)
row_idx = 0
# for each page, find all the urls
for page_id in range(1,2573+1):
    # page_url
    page_url = ""
    # find all the urls
    curr_urls = []
    
    while True:
        time.sleep(1)
#         SCSF_id = str(case_id).zfill(8)
        SCSF_id = str(1)
        if case_id%100 == 0:
            print case_id
        # for debug
#         SCSF_id = str(5117)
        cnki_head = "http://www.std.gov.cn/db/search/stdDBDetailed?id="
#         cnki_tail = "&urlid=&yx=&uid=WEEvREcwSlJHSldRa1FhcEE0L01SRzYzSVRPM1NjNDF0TUVFZ0xTdEQ4MD0=$9A4hF_YAuvQ5obgVAqNKPCYcEjKensW4ggI8Fm4gTkoUKaID8j8gFw!!"
#         cnki_url = cnki_head + SCSF_id + cnki_tail
        cnki_url = cnki_head + SCSF_id
        # print cnki_url
        try:
            response = urllib2.urlopen(cnki_url)  
        except urllib2.URLError, e:
            print str(e.reason)
            continue
        break
    html = response.read()  
#     print html
#     pdb.set_trace()
    #？？？？？
    if "未找到该条记录" in html:
        continue
    sp = html.split("\n")
    # SCSF_id = "SCSF00000170"

    # print sp
    for i, info in enumerate(sp):
        if "TC号/SC号" in info:
#             pdb.set_trace()
            tag_sp = sp[i + 1].split('<td align="left" >')
            tc_number = tag_sp[-1].strip("</td>\r")
#             print tc_number
        if "TC/SWG名称" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            tc_name = tag_sp[-1].strip("</td>\r")
#             print tc_name

        if "负责专业范围" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            prof_range =  tag_sp[-1].strip("</td>\r")
#             print prof_range

        if "秘书长" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            mishuzhang = tag_sp[-1].strip("</td>\r")
#             print mishuzhang

        if "秘书处所在单位" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            mishuzhang_dept = tag_sp[-1].strip("</td>\r")
#             print mishuzhang_dept

        if "单位地址" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            addr =  tag_sp[-1].strip("</td>\r")
#             print "address", addr

        if "联系人" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            contact =  tag_sp[-1].strip("</td>\r")
#             print "contact", contact

        if "邮政编码" in info and "bottom content" not in info:
#             pdb.set_trace()
            tag_sp = sp[i + 1].split('<td align="left" >')
            zip_code = tag_sp[-1].strip("</td>\r")
#             print "zip_code", zip_code


        if "电话" in info:
            # print "haha"
            tag_sp = sp[i + 1].split('<td align="left" >')
            tel = tag_sp[-1].strip("</td>\r")
#             print "tel", tel

        if "传真" in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            fax = tag_sp[-1].strip("</td>\r")
#             print "fax", fax

        if "邮箱" in info and "邮箱登录" not in info:
            tag_sp = sp[i + 1].split('<td align="left" >')
            email = tag_sp[-1].strip("</td>\r")
#             print "email", email,'\n'
    
    output_tbl = [SCSF_id, tc_number, tc_name, prof_range, mishuzhang, mishuzhang_dept, addr, contact, zip_code, tel, fax, email]
#     pdb.set_trace()
    if len(tc_number) > 0:
        # encode unit-8 (chinese)
        [table.write(row_idx, i, output_tbl[i]) for i in range(len(output_tbl))]
        row_idx += 1
        tc_number = []
#         print >> output, "\t".join(output_tbl)

output.save("/Volumes/data1/yefei_new14makeup.xls")
# Out:
# Automatic pdb calling has been turned ON
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900

# %%
# Out:
# 0
